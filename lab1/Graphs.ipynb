# %%
#import cvxpy as cp
import numpy as np
import pandas as pd
import time
import numpy.linalg as ln
from scipy.sparse import csr_matrix

# %%
   
with open('nothr.txt') as f:
    contents = f.read()
    #print(contents)

b = [0]*100
a = [0]*100
c = contents.split("\n")
#print(len(contents))
for i in range(100):
    #print(c[i])
    
    b[i] = c[i].split(" ")
    b[i][0] = float(b[i][0])
    b[i][1] = float(b[i][1])
    a[i] = b[i][1]
    #print(contents.split("\n"))
   # b[i] = contents[i][1]
    #c[i] = contents[i][0]
import matplotlib.pyplot as plt
#print(a)
#plt.hist(a)

x = np.arange(1, 101, 1)
plt.scatter(x, a)
a_no = a
plt.ylabel('time, sec')
plt.xlabel('matrix size')
plt.title("1) Время умножения матриц от размера матриц для наивной однопоточной реализации") # заголовок
plt.show()

# %%
with open('1_thread.txt') as f:
    contents = f.read()
    #print(contents)
b = [0]*100
a = [0]*100
c = contents.split("\n")
#print(len(contents))
for i in range(100):
    #print(c[i])
    
    b[i] = c[i].split(" ")
    b[i][0] = float(b[i][0])
    b[i][1] = float(b[i][1])
    a[i] = b[i][1]
    #print(contents.split("\n"))
   # b[i] = contents[i][1]
    #c[i] = contents[i][0]
import matplotlib.pyplot as plt
#print(a)
#plt.hist(a)

import numpy as np
import matplotlib.pyplot as plt
x = np.arange(1, 101, 1)
#plt.scatter(x, np.log(a))
a_1 = a
plt.scatter(x, a_1)
plt.ylabel('time, sec')
plt.xlabel('matrix size')
plt.title("2) время умножения матриц от размера матриц для блочного умножения в 1 поток") # заголовок
plt.show()

# %%
with open('3_task.txt') as f:
    contents = f.read()
    #print(contents)
    
n = 8    #100
b = [0]*n
a = [0]*n
c = contents.split("\n")
#print(len(contents))
for i in range(n):
    #print(c[i])
    
    b[i] = c[i].split(" ")
    b[i][0] = float(b[i][0])
    b[i][1] = float(b[i][1])
    a[i] = b[i][1]
    #print(contents.split("\n"))
   # b[i] = contents[i][1]
    #c[i] = contents[i][0]
import matplotlib.pyplot as plt
#print(a)
#plt.hist(a)

import numpy as np
import matplotlib.pyplot as plt
x = np.arange(1, n+1, 1)
#plt.scatter(x, np.log(a))
a_1 = a
plt.scatter(x, a_1)
plt.ylabel('time, sec')
plt.xlabel('Number of threads')
plt.title("3) время умножения матриц от количества тредов для блочной реализации") # заголовок
plt.show()

# %%
with open('size_50_threads.txt') as f:
    contents = f.read()
    #print(contents)
n = 8 #52
b = [0]*n
a = [0]*n
c = contents.split("\n")
#print(len(contents))
for i in range(n):
    #print(c[i])
    
    b[i] = c[i].split(" ")
    b[i][0] = float(b[i][0])
    b[i][1] = float(b[i][1])
    a[i] = b[i][1]
    #print(contents.split("\n"))
   # b[i] = contents[i][1]
    #c[i] = contents[i][0]
import matplotlib.pyplot as plt
#print(a)
#plt.hist(a)

x = np.arange(1, n+1, 1)
plt.scatter(x, a)
a_6 = a
plt.ylabel('time, sec')
plt.xlabel('Number of threads')
plt.title("4) время умножения матриц от количества тредов для блочной реализации") # заголовок
plt.show()

# %%
size_50_threads.txt

# %%
with open('3-thread.txt') as f:
    contents = f.read()
    #print(contents)

b = [0]*100
a = [0]*100
c = contents.split("\n")
#print(len(contents))
for i in range(100):
    #print(c[i])
    
    b[i] = c[i].split(" ")
    b[i][0] = float(b[i][0])
    b[i][1] = float(b[i][1])
    a[i] = b[i][1]
    #print(contents.split("\n"))
   # b[i] = contents[i][1]
    #c[i] = contents[i][0]
import matplotlib.pyplot as plt
#print(a)
#plt.hist(a)

x = np.arange(1, 101, 1)
#plt.scatter(x,np.log(a))
#plt.scatter(x, a)
a_3 = a
#plt.ylabel('time, sec')
#plt.xlabel('matrix rank')
#plt.show()

# %%
with open('6_th.txt') as f:
    contents = f.read()
    #print(contents)

b = [0]*100
a = [0]*100
c = contents.split("\n")
#print(len(contents))
for i in range(100):
    #print(c[i])
    
    b[i] = c[i].split(" ")
    b[i][0] = float(b[i][0])
    b[i][1] = float(b[i][1])
    a[i] = b[i][1]
    #print(contents.split("\n"))
   # b[i] = contents[i][1]
    #c[i] = contents[i][0]
import matplotlib.pyplot as plt
#print(a)
#plt.hist(a)

x = np.arange(1, 101, 1)
#plt.scatter(x, a)
a_6 = a
#plt.ylabel('time, sec')
#plt.xlabel('matrix size')
plt.show()
